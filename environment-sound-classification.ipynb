# %% [markdown]
# ## Project on Environment Sound Classification. Submitted by Gupta, Amit

# %% [markdown]
# Dataset description in this notebook has been directly taken from https://github.com/karoldvl/ESC-50
#
# ESC-50 dataset can also be downloaded from here: https://www.kaggle.com/mmoreaux/environmental-sound-classification-50

# %% [markdown]
# ## ESC-50: Dataset for Environmental Sound Classification
#
#
# The **ESC-50 dataset** is a labeled collection of 2000 environmental audio recordings suitable for benchmarking methods of environmental sound classification.
#
# The dataset consists of 5-second-long recordings organized into 50 semantical classes (with 40 examples per class) loosely arranged into 5 major categories:
#
# | <sub>Animals</sub> | <sub>Natural soundscapes & water sounds </sub> | <sub>Human, non-speech sounds</sub> | <sub>Interior/domestic sounds</sub> | <sub>Exterior/urban noises</sub> |
# | :--- | :--- | :--- | :--- | :--- |
# | <sub>Dog</sub> | <sub>Rain</sub> | <sub>Crying baby</sub> | <sub>Door knock</sub> | <sub>Helicopter</sub></sub> |
# | <sub>Rooster</sub> | <sub>Sea waves</sub> | <sub>Sneezing</sub> | <sub>Mouse click</sub> | <sub>Chainsaw</sub> |
# | <sub>Pig</sub> | <sub>Crackling fire</sub> | <sub>Clapping</sub> | <sub>Keyboard typing</sub> | <sub>Siren</sub> |
# | <sub>Cow</sub> | <sub>Crickets</sub> | <sub>Breathing</sub> | <sub>Door, wood creaks</sub> | <sub>Car horn</sub> |
# | <sub>Frog</sub> | <sub>Chirping birds</sub> | <sub>Coughing</sub> | <sub>Can opening</sub> | <sub>Engine</sub> |
# | <sub>Cat</sub> | <sub>Water drops</sub> | <sub>Footsteps</sub> | <sub>Washing machine</sub> | <sub>Train</sub> |
# | <sub>Hen</sub> | <sub>Wind</sub> | <sub>Laughing</sub> | <sub>Vacuum cleaner</sub> | <sub>Church bells</sub> |
# | <sub>Insects (flying)</sub> | <sub>Pouring water</sub> | <sub>Brushing teeth</sub> | <sub>Clock alarm</sub> | <sub>Airplane</sub> |
# | <sub>Sheep</sub> | <sub>Toilet flush</sub> | <sub>Snoring</sub> | <sub>Clock tick</sub> | <sub>Fireworks</sub> |
# | <sub>Crow</sub> | <sub>Thunderstorm</sub> | <sub>Drinking, sipping</sub> | <sub>Glass breaking</sub> | <sub>Hand saw</sub> |
#
# Clips in this dataset have been manually extracted from public field recordings gathered by the **[Freesound.org project](http://freesound.org/)**. The dataset has been prearranged into 5 folds for comparable cross-validation, making sure that fragments from the same original source file are contained in a single fold.
#
# A more thorough description of the dataset is available in the original [paper](http://karol.piczak.com/papers/Piczak2015-ESC-Dataset.pdf) with some supplementary materials on GitHub: **[ESC: Dataset for Environmental Sound Classification - paper replication data](https://github.com/karoldvl/paper-2015-esc-dataset)**.
#
#
# ## Download
#
# The dataset can be downloaded as a single .zip file (~600 MB):
#
# **[Download ESC-50 dataset](https://github.com/karoldvl/ESC-50/archive/master.zip)**
#
#
# ## Results
#
# Numerous machine learning & signal processing approaches have been evaluated on the ESC-50 dataset. Most of them are listed here.
#
# > ###### Terms used in the table:
# >
# > <sub>• CNN - Convolutional Neural Network<br />• CRNN - Convolutional Recurrent Neural Network<br />• GMM - Gaussian Mixture Model<br />• GTCC - Gammatone Cepstral Coefficients<br />• GTSC - Gammatone Spectral Coefficients<br />• k-NN - k-Neareast Neighbors<br />• MFCC - Mel-Frequency Cepstral Coefficients<br />• MLP - Multi-Layer Perceptron<br />• RBM - Restricted Boltzmann Machine<br />• RNN - Recurrent Neural Network<br />• SVM - Support Vector Machine<br />• TEO - Teager Energy Operator<br />• ZCR - Zero-Crossing Rate</sub>
#
# | <sub>Title</sub> | <sub>Notes</sub> | <sub>Accuracy</sub> | <sub>Paper</sub> | <sub>Code</sub> |
# | :--- | :--- | :--- | :--- | :--- |
# | <sub>**Unsupervised Filterbank Learning Using Convolutional Restricted Boltzmann Machine for Environmental Sound Classification**</sub> | <sub>CNN with filterbanks learned using convolutional RBM + fusion with GTSC and mel energies</sub> | <sub>86.50%</sub> | <sub>[sailor2017](https://pdfs.semanticscholar.org/f6fd/1be38a2d764d900b11b382a379efe88b3ed6.pdf)</sub> |  |
# | <sub>**Learning from Between-class Examples for Deep Sound Recognition**</sub> | <sub>EnvNet-v2 ([tokozume2017a](http://www.mi.t.u-tokyo.ac.jp/assets/publication/LEARNING_ENVIRONMENTAL_SOUNDS_WITH_END-TO-END_CONVOLUTIONAL_NEURAL_NETWORK-poster.pdf)) + data augmentation + Between-Class learning</sub> | <sub>84.90%</sub> | <sub>[tokozume2017b](https://openreview.net/forum?id=B1Gi6LeRZ)</sub> |  |
# | <sub>**Novel Phase Encoded Mel Filterbank Energies for Environmental Sound Classification**</sub> | <sub>CNN working with phase encoded mel filterbank energies (PEFBEs), fusion with Mel energies</sub> | <sub>84.15%</sub> | <sub>[tak2017](https://www.researchgate.net/profile/Dharmesh_Agrawal/publication/320733074_Novel_Phase_Encoded_Mel_Filterbank_Energies_for_Environmental_Sound_Classification/links/5a084c780f7e9b68229c8947/Novel-Phase-Encoded-Mel-Filterbank-Energies-for-Environmental-Sound-Classification.pdf)</sub> |  |
# | <sub>**Knowledge Transfer from Weakly Labeled Audio using Convolutional Neural Network for Sound Events and Scenes**</sub> | <sub>CNN pretrained on AudioSet</sub> | <sub>83.50%</sub> | <sub>[kumar2017](https://arxiv.org/pdf/1711.01369.pdf)</sub> | <a href="https://github.com/anuragkr90/weak_feature_extractor">:scroll:</a> |
# | <sub>**Unsupervised Filterbank Learning Using Convolutional Restricted Boltzmann Machine for Environmental Sound Classification**</sub> | <sub>CNN with filterbanks learned using convolutional RBM + fusion with GTSC</sub> | <sub>83.00%</sub> | <sub>[sailor2017](https://pdfs.semanticscholar.org/f6fd/1be38a2d764d900b11b382a379efe88b3ed6.pdf)</sub> |  |
# | <sub>**Novel TEO-based Gammatone Features for Environmental Sound Classification**</sub> | <sub>Fusion of GTSC & TEO-GTSC with CNN</sub> | <sub>81.95%</sub> | <sub>[agrawal2017](http://www.eurasip.org/Proceedings/Eusipco/Eusipco2017/papers/1570347591.pdf)</sub> |  |
# | <sub>**Learning from Between-class Examples for Deep Sound Recognition**</sub> | <sub>EnvNet-v2 ([tokozume2017a](http://www.mi.t.u-tokyo.ac.jp/assets/publication/LEARNING_ENVIRONMENTAL_SOUNDS_WITH_END-TO-END_CONVOLUTIONAL_NEURAL_NETWORK-poster.pdf)) + Between-Class learning</sub> | <sub>81.80%</sub> | <sub>[tokozume2017b](https://openreview.net/forum?id=B1Gi6LeRZ)</sub> |  |
# | :headphones: <sub>***Human accuracy***</sub> | <sub>Crowdsourcing experiment in classifying ESC-50 by human listeners</sub> | <sub>81.30%</sub> | <sub>[piczak2015a](http://karol.piczak.com/papers/Piczak2015-ESC-Dataset.pdf)</sub> | <a href="https://github.com/karoldvl/paper-2015-esc-dataset">:scroll:</a> |
# | <sub>**Objects that Sound**</sub> | <sub>*Look, Listen and Learn* (L3) network ([arandjelovic2017a](https://arxiv.org/pdf/1705.08168.pdf)) with stride 2, larger batches and learning rate schedule</sub> | <sub>79.80%</sub> | <sub>[arandjelovic2017b](https://arxiv.org/pdf/1712.06651.pdf)</sub> |  |
# | <sub>**Look, Listen and Learn**</sub> | <sub>8-layer convolutional subnetwork pretrained on an audio-visual correspondence task</sub> | <sub>79.30%</sub> | <sub>[arandjelovic2017a](https://arxiv.org/pdf/1705.08168.pdf)</sub> |  |
# | <sub>**Learning Environmental Sounds with Multi-scale Convolutional Neural Network**</sub> | <sub>Multi-scale convolutions with feature fusion (waveform + spectrogram)</sub> | <sub>79.10%</sub> | <sub>[zhu2018](https://arxiv.org/pdf/1803.10219.pdf)</sub> |  |
# | <sub>**Novel TEO-based Gammatone Features for Environmental Sound Classification**</sub> | <sub>GTSC with CNN</sub> | <sub>79.10%</sub> | <sub>[agrawal2017](http://www.eurasip.org/Proceedings/Eusipco/Eusipco2017/papers/1570347591.pdf)</sub> |  |
# | <sub>**Learning from Between-class Examples for Deep Sound Recognition**</sub> | <sub>EnvNet-v2 ([tokozume2017a](http://www.mi.t.u-tokyo.ac.jp/assets/publication/LEARNING_ENVIRONMENTAL_SOUNDS_WITH_END-TO-END_CONVOLUTIONAL_NEURAL_NETWORK-poster.pdf)) + data augmentation</sub> | <sub>78.80%</sub> | <sub>[tokozume2017b](https://openreview.net/forum?id=B1Gi6LeRZ)</sub> |  |
# | <sub>**Unsupervised Filterbank Learning Using Convolutional Restricted Boltzmann Machine for Environmental Sound Classification**</sub> | <sub>CNN with filterbanks learned using convolutional RBM</sub> | <sub>78.45%</sub> | <sub>[sailor2017](https://pdfs.semanticscholar.org/f6fd/1be38a2d764d900b11b382a379efe88b3ed6.pdf)</sub> |  |
# | <sub>**Learning from Between-class Examples for Deep Sound Recognition**</sub> | <sub>Baseline CNN ([piczak2015b](http://karol.piczak.com/papers/Piczak2015-ESC-ConvNet.pdf)) + Batch Normalization + Between-Class learning</sub> | <sub>76.90%</sub> | <sub>[tokozume2017b](https://openreview.net/forum?id=B1Gi6LeRZ)</sub> |  |
# | <sub>**Novel TEO-based Gammatone Features for Environmental Sound Classification**</sub> | <sub>TEO-GTSC with CNN</sub> | <sub>74.85%</sub> | <sub>[agrawal2017](http://www.eurasip.org/Proceedings/Eusipco/Eusipco2017/papers/1570347591.pdf)</sub> |  |
# | <sub>**Learning from Between-class Examples for Deep Sound Recognition**</sub> | <sub>EnvNet-v2 ([tokozume2017a](http://www.mi.t.u-tokyo.ac.jp/assets/publication/LEARNING_ENVIRONMENTAL_SOUNDS_WITH_END-TO-END_CONVOLUTIONAL_NEURAL_NETWORK-poster.pdf))</sub> | <sub>74.40%</sub> | <sub>[tokozume2017b](https://openreview.net/forum?id=B1Gi6LeRZ)</sub> |  |
# | <sub>**Soundnet: Learning sound representations from unlabeled video**</sub> | <sub>8-layer CNN (raw audio) with transfer learning from unlabeled videos</sub> | <sub>74.20%</sub> | <sub>[aytar2016](http://papers.nips.cc/paper/6146-soundnet-learning-sound-representations-from-unlabeled-video.pdf)</sub> | <a href="https://github.com/cvondrick/soundnet">:scroll:</a> |
# | <sub>**Learning from Between-class Examples for Deep Sound Recognition**</sub> | <sub>18-layer CNN on raw waveforms ([dai2016](https://arxiv.org/pdf/1610.00087.pdf)) + Between-Class learning</sub> | <sub>73.30%</sub> | <sub>[tokozume2017b](https://openreview.net/forum?id=B1Gi6LeRZ)</sub> |  |
# | <sub>**Novel Phase Encoded Mel Filterbank Energies for Environmental Sound Classification**</sub> | <sub>CNN working with phase encoded mel filterbank energies (PEFBEs)</sub> | <sub>73.25%</sub> | <sub>[tak2017](https://www.researchgate.net/profile/Dharmesh_Agrawal/publication/320733074_Novel_Phase_Encoded_Mel_Filterbank_Energies_for_Environmental_Sound_Classification/links/5a084c780f7e9b68229c8947/Novel-Phase-Encoded-Mel-Filterbank-Energies-for-Environmental-Sound-Classification.pdf)</sub> |  |
# | <sub>**Classifying environmental sounds using image recognition networks**</sub> | <sub>16 kHz sampling rate, GoogLeNet on spectrograms (40 ms frame length)</sub> | <sub>73.20%</sub> | <sub>[boddapati2017](https://www.sciencedirect.com/science/article/pii/S1877050917316599)</sub> | <a href="https://github.com/bkasvenkatesh/Classifying-Environmental-Sounds-with-Image-Networks">:scroll:</a> |
# | <sub>**Learning from Between-class Examples for Deep Sound Recognition**</sub> | <sub>Baseline CNN ([piczak2015b](http://karol.piczak.com/papers/Piczak2015-ESC-ConvNet.pdf)) + Batch Normalization</sub> | <sub>72.40%</sub> | <sub>[tokozume2017b](https://openreview.net/forum?id=B1Gi6LeRZ)</sub> |  |
# | <sub>**Novel TEO-based Gammatone Features for Environmental Sound Classification**</sub> | <sub>Fusion of MFCC & TEO-GTCC with GMM</sub> | <sub>72.25%</sub> | <sub>[agrawal2017](http://www.eurasip.org/Proceedings/Eusipco/Eusipco2017/papers/1570347591.pdf)</sub> |  |
# | <sub>**Learning environmental sounds with end-to-end convolutional neural network (EnvNet)**</sub> | <sub>Combination of spectrogram and raw waveform CNN</sub> | <sub>71.00%</sub> | <sub>[tokozume2017a](http://www.mi.t.u-tokyo.ac.jp/assets/publication/LEARNING_ENVIRONMENTAL_SOUNDS_WITH_END-TO-END_CONVOLUTIONAL_NEURAL_NETWORK-poster.pdf)</sub> |  |
# | <sub>**Novel TEO-based Gammatone Features for Environmental Sound Classification**</sub> | <sub>TEO-GTCC with GMM</sub> | <sub>68.85%</sub> | <sub>[agrawal2017](http://www.eurasip.org/Proceedings/Eusipco/Eusipco2017/papers/1570347591.pdf)</sub> |  |
# | <sub>**Classifying environmental sounds using image recognition networks**</sub> | <sub>16 kHz sampling rate, AlexNet on spectrograms (30 ms frame length)</sub> | <sub>68.70%</sub> | <sub>[boddapati2017](https://www.sciencedirect.com/science/article/pii/S1877050917316599)</sub> | <a href="https://github.com/bkasvenkatesh/Classifying-Environmental-Sounds-with-Image-Networks">:scroll:</a> |
# | <sub>**Very Deep Convolutional Neural Networks for Raw Waveforms**</sub> | <sub>18-layer CNN on raw waveforms</sub> | <sub>68.50%</sub> | <sub>[dai2016](https://arxiv.org/pdf/1610.00087.pdf), [tokozume2017b](https://openreview.net/forum?id=B1Gi6LeRZ)</sub> | <a href="https://github.com/philipperemy/very-deep-convnets-raw-waveforms">:scroll:</a> |
# | <sub>**Classifying environmental sounds using image recognition networks**</sub> | <sub>32 kHz sampling rate, GoogLeNet on spectrograms (30 ms frame length)</sub> | <sub>67.80%</sub> | <sub>[boddapati2017](https://www.sciencedirect.com/science/article/pii/S1877050917316599)</sub> | <a href="https://github.com/bkasvenkatesh/Classifying-Environmental-Sounds-with-Image-Networks">:scroll:</a> |
# | <sub>**WSNet: Learning Compact and Efficient Networks with Weight Sampling**</sub> | <sub>SoundNet 8-layer CNN architecture with 100x model compression</sub> | <sub>66.25%</sub> | <sub>[jin2017](https://openreview.net/forum?id=H1I3M7Z0b)</sub> |  |
# | <sub>**Soundnet: Learning sound representations from unlabeled video**</sub> | <sub>5-layer CNN (raw audio) with transfer learning from unlabeled videos</sub> | <sub>66.10%</sub> | <sub>[aytar2016](http://papers.nips.cc/paper/6146-soundnet-learning-sound-representations-from-unlabeled-video.pdf)</sub> | <a href="https://github.com/cvondrick/soundnet">:scroll:</a> |
# | <sub>**WSNet: Learning Compact and Efficient Networks with Weight Sampling**</sub> | <sub>SoundNet 8-layer CNN architecture with 180x model compression</sub> | <sub>65.80%</sub> | <sub>[jin2017](https://openreview.net/forum?id=H1I3M7Z0b)</sub> |  |
# | <sub>**Soundnet: Learning sound representations from unlabeled video**</sub> | <sub>5-layer CNN trained on raw audio of ESC-50 only</sub> | <sub>65.00%</sub> | <sub>[aytar2016](http://papers.nips.cc/paper/6146-soundnet-learning-sound-representations-from-unlabeled-video.pdf)</sub> | <a href="https://github.com/cvondrick/soundnet">:scroll:</a> |
# | <sub>:bar_chart: **Environmental Sound Classification with Convolutional Neural Networks** - ***CNN baseline***</sub> | <sub>CNN with 2 convolutional and 2 fully-connected layers, mel-spectrograms as input, vertical filters in the first layer</sub> | <sub>64.50%</sub> | <sub>[piczak2015b](http://karol.piczak.com/papers/Piczak2015-ESC-ConvNet.pdf)</sub> | <a href="https://github.com/karoldvl/paper-2015-esc-convnet">:scroll:</a> |
# | <sub>**auDeep: Unsupervised Learning of Representations from Audio with Deep Recurrent Neural Networks**</sub> | <sub>MLP classifier on features extracted with an RNN autoencoder</sub> | <sub>64.30%</sub> | <sub>[freitag2017](https://arxiv.org/pdf/1712.04382.pdf)</sub> | <a href="https://github.com/auDeep/auDeep">:scroll:</a> |
# | <sub>**Classifying environmental sounds using image recognition networks**</sub> | <sub>32 kHz sampling rate, AlexNet on spectrograms (30 ms frame length)</sub> | <sub>63.20%</sub> | <sub>[boddapati2017](https://www.sciencedirect.com/science/article/pii/S1877050917316599)</sub> | <a href="https://github.com/bkasvenkatesh/Classifying-Environmental-Sounds-with-Image-Networks">:scroll:</a> |
# | <sub>**Classifying environmental sounds using image recognition networks**</sub> | <sub>CRNN</sub> | <sub>60.30%</sub> | <sub>[boddapati2017](https://www.sciencedirect.com/science/article/pii/S1877050917316599)</sub> | <a href="https://github.com/bkasvenkatesh/Classifying-Environmental-Sounds-with-Image-Networks">:scroll:</a> |
# | <sub>**Comparison of Time-Frequency Representations for Environmental Sound Classification using Convolutional Neural Networks**</sub> | <sub>3-layer CNN with vertical filters on wideband mel-STFT (*median accuracy*)</sub> | <sub>*56.37%*</sub> | <sub>[huzaifah2017](https://arxiv.org/pdf/1706.07156.pdf)</sub> |  |
# | <sub>**Comparison of Time-Frequency Representations for Environmental Sound Classification using Convolutional Neural Networks**</sub> | <sub>3-layer CNN with square filters on wideband mel-STFT (*median accuracy*)</sub> | <sub>*54.00%*</sub> | <sub>[huzaifah2017](https://arxiv.org/pdf/1706.07156.pdf)</sub> |  |
# | <sub>**Soundnet: Learning sound representations from unlabeled video**</sub> | <sub>8-layer CNN trained on raw audio of ESC-50 only</sub> | <sub>51.10%</sub> | <sub>[aytar2016](http://papers.nips.cc/paper/6146-soundnet-learning-sound-representations-from-unlabeled-video.pdf)</sub> | <a href="https://github.com/cvondrick/soundnet">:scroll:</a> |
# | <sub>**Comparison of Time-Frequency Representations for Environmental Sound Classification using Convolutional Neural Networks**</sub> | <sub>5-layer CNN with square filters on wideband mel-STFT (*median accuracy*)</sub> | <sub>*50.87%*</sub> | <sub>[huzaifah2017](https://arxiv.org/pdf/1706.07156.pdf)</sub> |  |
# | <sub>**Comparison of Time-Frequency Representations for Environmental Sound Classification using Convolutional Neural Networks**</sub> | <sub>5-layer CNN with vertical filters on wideband mel-STFT (*median accuracy*)</sub> | <sub>*46.25%*</sub> | <sub>[huzaifah2017](https://arxiv.org/pdf/1706.07156.pdf)</sub> |  |
# | :bar_chart: <sub>***Baseline - random forest***</sub> | <sub>Baseline ML approach (MFCC & ZCR + random forest)</sub> | <sub>44.30%</sub> | <sub>[piczak2015a](http://karol.piczak.com/papers/Piczak2015-ESC-Dataset.pdf)</sub> | <a href="https://github.com/karoldvl/paper-2015-esc-dataset">:scroll:</a> |
# | <sub>**Soundnet: Learning sound representations from unlabeled video**</sub> | <sub>Convolutional autoencoder trained on unlabeled videos</sub> | <sub>39.90%</sub> | <sub>[aytar2016](http://papers.nips.cc/paper/6146-soundnet-learning-sound-representations-from-unlabeled-video.pdf)</sub> | <a href="https://github.com/cvondrick/soundnet">:scroll:</a> |
# | :bar_chart: <sub>***Baseline - SVM***</sub> | <sub>Baseline ML approach (MFCC & ZCR + SVM)</sub> | <sub>39.60%</sub> | <sub>[piczak2015a](http://karol.piczak.com/papers/Piczak2015-ESC-Dataset.pdf)</sub> | <a href="https://github.com/karoldvl/paper-2015-esc-dataset">:scroll:</a> |
# | :bar_chart: <sub>***Baseline - k-NN***</sub> | <sub>Baseline ML approach (MFCC & ZCR + k-NN)</sub> | <sub>32.20%</sub> | <sub>[piczak2015a](http://karol.piczak.com/papers/Piczak2015-ESC-Dataset.pdf)</sub> | <a href="https://github.com/karoldvl/paper-2015-esc-dataset">:scroll:</a> |
# | <sub>**A mixture model-based real-time audio sources classification method**</sub> | <sub>Dictionary of sound models used for classification (*accuracy is computed on segments instead of files*)</sub> | <sub>*94.00%*</sub> | <sub>[baelde2017](https://hal.archives-ouvertes.fr/hal-01420677v2/document)</sub> |  |
# | <sub>**NELS - Never-Ending Learner of Sounds**</sub> | <sub>Large-scale audio crawling with classifiers trained on AED datasets (including ESC-50)</sub> | <sub>N/A</sub> | <sub>[elizalde2017](http://media.aau.dk/smc/wp-content/uploads/2017/12/ML4AudioNIPS17_paper_3.pdf)</sub> | <a href="http://nels.cs.cmu.edu/">:scroll:</a> |
# | <sub>**Utilizing Domain Knowledge in End-to-End Audio Processing**</sub> | <sub>End-to-end CNN with learned mel-spectrogram transformation</sub> | <sub>N/A</sub> | <sub>[tax2017](https://arxiv.org/pdf/1712.00254.pdf)</sub> | <a href="https://github.com/corticph/MSTmodel">:scroll:</a> |
# | <sub>**Deep Neural Network based learning and transferring mid-level audio features for acoustic scene classification**</sub> | <sub>Transfer learning from various datasets, including ESC-50</sub> | <sub>N/A</sub> | <sub>[mun2017](https://pdfs.semanticscholar.org/5f1e/513aec29b8c471723172f1d5bc2174daa71a.pdf)</sub> |  |
# | <sub>**Features and Kernels for Audio Event Recognition**</sub> | <sub>MFCC, GMM, SVM</sub> | <sub>N/A</sub> | <sub>[kumar2016b](https://arxiv.org/pdf/1607.05765.pdf)</sub> |  |
# | <sub>**A real-time environmental sound recognition system for the Android OS**</sub> | <sub>Real-time sound recognition for Android evaluated on ESC-10</sub> | <sub>N/A</sub> | <sub>[pillos2016](https://www.cs.tut.fi/sgn/arg/dcase2016/documents/workshop/Pillos-DCASE2016workshop.pdf)</sub> |  |
# | <sub>**Comparing Time and Frequency Domain for Audio Event Recognition Using Deep Learning**</sub> | <sub>Discriminatory effectiveness of different signal representations compared on ESC-10 and Freiburg-106</sub> | <sub>N/A</sub> | <sub>[hertel2016](https://arxiv.org/pdf/1603.05824.pdf)</sub> |  |
# | <sub>**Audio Event and Scene Recognition: A Unified Approach using Strongly and Weakly Labeled Data**</sub> | <sub>Combination of weakly labeled data (YouTube) with strong labeling (ESC-10) for Acoustic Event Detection</sub> | <sub>N/A</sub> | <sub>[kumar2016a](https://arxiv.org/pdf/1611.04871.pdf)</sub> |  |
#
#
# ## Repository content
#
# - [`audio/*.wav`](audio/)
#
#   2000 audio recordings in WAV format (5 seconds, 44.1 kHz, mono) with the following naming convention:
#
#   `{FOLD}-{CLIP_ID}-{TAKE}-{TARGET}.wav`
#
#   - `{FOLD}` - index of the cross-validation fold,
#   - `{CLIP_ID}` - ID of the original Freesound clip,
#   - `{TAKE}` - letter disambiguating between different fragments from the same Freesound clip,
#   - `{TARGET}` - class in numeric format [0, 49].
#
# - [`meta/esc50.csv`](meta/esc50.csv)
#
#   CSV file with the following structure:
#
#   | <sub>filename</sub> | <sub>fold</sub> | <sub>target</sub> | <sub>category</sub> | <sub>esc10</sub> | <sub>src_file</sub> | <sub>take</sub> |
#   | :--- | :--- | :--- | :--- | :--- | :--- | :--- |
#
#   The `esc10` column indicates if a given file belongs to the *ESC-10* subset (10 selected classes, CC BY license).
#
# - [`meta/esc50-human.xlsx`](meta/esc50-human.xlsx)
#
#   Additional data pertaining to the crowdsourcing experiment (human classification accuracy).
#
#
# ## License
#
# The dataset is available under the terms of the [Creative Commons Attribution Non-Commercial license](http://creativecommons.org/licenses/by-nc/3.0/).
#
# A smaller subset (clips tagged as *ESC-10*) is distributed under CC BY (Attribution).
#
# Attributions for each clip are available in the [ LICENSE file](LICENSE).

# %% [markdown]
# ### SUMMARY
# ### This notebook contains the final implementation that has given the best results. Several ideas were tried out before getting to 94+ % accuracy.
# ### Main contributor to the accuracy bump was data augmentation. The initial dataset from ESC-50 contains only 40 samples for each sound. These 40 samples were augmented with another 40 samples with varying +-24 db to each of the 40 samples effectively doubling the sample set from 40 samples to 80 samples.
# ### With this simple data augmentation trick, validation accuracy shot up by 50 points (45% to 94%).
# ### The deep learning network configuration is the same as the one used in Assignment 12. I felt no change was necessary to this configuration, as this network was giving excellent results.
# ### The frequency range of the environmental sounds ranges from 0-11KHz which is different from human speech which has a range of 0-8 KHz. These can be seen from the various spectrograms and FFT plots below.
# ### For this reason, the sampling frequency was kept at ~22 KHz to not lose (Nyquist criterion) any information.
# ### All the routines in this notebook borrow heavily from Assignment 12. One routine was added for data augmentation (random_gain), and code was added to parse and organize the ESC-50 dataset so that it could be ingested by save_data_to_array() routine.
#
# ### At the very end of the notebook, I have also shown the results without data augmentation. The test validation accuracy is 44.5%. This shows the importance of data augmentation approach for small sample data sets.

# %%
import os
from os.path import isdir, join
from pathlib import Path
import pandas as pd

# Math
import numpy as np
import random
from scipy.fftpack import fft
from scipy import signal
from scipy.io import wavfile
import librosa

from sklearn.decomposition import PCA

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import IPython.display as ipd
import librosa.display

import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import pandas as pd

# directory management
from shutil import copyfile

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# IMPORTANT: PLEASE READ: After downloading the dataset from https://www.kaggle.com/mmoreaux/environmental-sound-classification-50, 
# and unzipping, please place the directory environmental-sound-classification-50 and 
# its sub-directory and contents under ./data as shown the DATA_PATH below.

# all the common routines go here

import librosa
import os
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import numpy as np
from tqdm import tqdm

DATA_PATH = './data/environmental-sound-classification-50/audio/data/'


# Input: Folder Path
# Output: Tuple (Label, Indices of the labels, one-hot encoded labels)
def get_labels(path=DATA_PATH):
    labels = os.listdir(path)
    label_indices = np.arange(0, len(labels))
    return labels, label_indices, to_categorical(label_indices)


# Handy function to convert wav2mfcc
def wav2mfcc(file_path, max_len=144):
    wave, sr = librosa.load(file_path, mono=True, sr=None)
    #print(f'wave={wave}, wave shape={wave.shape}')
    wave = wave[::3]
    #mfcc = librosa.feature.mfcc(wave, sr=16000)
    mfcc = librosa.feature.mfcc(wave, sr=sr, n_mfcc=39)
    #print(f'mfcc shape = {mfcc.shape}')
    # If maximum length exceeds mfcc lengths then pad the remaining ones
    if (max_len > mfcc.shape[1]):
        pad_width = max_len - mfcc.shape[1]
        mfcc = np.pad(mfcc, pad_width=((0, 0), (0, pad_width)), mode='constant')

    # Else cutoff the remaining parts
    else:
        mfcc = mfcc[:, :max_len]
    
    return mfcc


def save_data_to_array(path=DATA_PATH, max_len=11):
    labels, _, _ = get_labels(path)
    
    print(f'labels={labels}')
    for label in labels:
        # Init mfcc vectors
        mfcc_vectors = []

        wavfiles = [path + label + '/' + wavfile for wavfile in os.listdir(path + '/' + label)]
        #print(f'wavefiles = {wavfiles}')
        for wavfile in tqdm(wavfiles, "Saving vectors of label - '{}'".format(label)):
            mfcc = wav2mfcc(wavfile, max_len=max_len)
            mfcc_vectors.append(mfcc)
        np.save(label + '.npy', mfcc_vectors)


def get_train_test(split_ratio=0.9, random_state=42):
    # Get available labels
    labels, indices, _ = get_labels(DATA_PATH)
    #print(f'labels={labels}, indices={indices}')

    # Getting first arrays
    X = np.load(labels[0] + '.npy')
    y = np.zeros(X.shape[0])
    #print(f'Xshape={X.shape}, yshape={y.shape}')
    # Append all of the dataset into one single array, same goes for y
    for i, label in enumerate(labels[1:]):
        #print(f'i={i}, label={label}')
        x = np.load(label + '.npy')
        X = np.vstack((X, x))
        y = np.append(y, np.full(x.shape[0], fill_value= (i + 1)))

    assert X.shape[0] == len(y)

    return train_test_split(X, y, test_size= (1 - split_ratio), random_state=random_state, shuffle=True)



def prepare_dataset(path=DATA_PATH):
    labels, _, _ = get_labels(path)
    data = {}
    for label in labels:
        data[label] = {}
        data[label]['path'] = [path  + label + '/' + wavfile for wavfile in os.listdir(path + '/' + label)]

        vectors = []

        for wavfile in data[label]['path']:
            wave, sr = librosa.load(wavfile, mono=True, sr=None)
            # Downsampling
            wave = wave[::3]
            mfcc = librosa.feature.mfcc(wave, sr=16000)
            vectors.append(mfcc)

        data[label]['mfcc'] = vectors

    return data


def load_dataset(path=DATA_PATH):
    data = prepare_dataset(path)

    dataset = []

    for key in data:
        for mfcc in data[key]['mfcc']:
            dataset.append((key, mfcc))

    return dataset[:100]


def random_gain(db):
    def f(sound):
        return sound * np.power(10, random.uniform(-db, db) / 20.0)

    return f

# %%
# read the csv file and place the sound samples under the correct label directoy 

csv_file = './data/environmental-sound-classification-50/esc50.csv'
df = pd.read_csv(csv_file)

# This routine creates a data directory under the audio directory and places the respective 
# .wav files under the correct labels
# example for "label' siren": './data/environmental-sound-classification-50/audio/data/siren/5-184323-A-42.wav'
# the data augmented files have a "gain" prefix. 
# Example: './data/environmental-sound-classification-50/audio/data/siren/gain_5-184323-A-42.wav'

target_base = './data/environmental-sound-classification-50/audio/data/'
target_esc10_base = './data/environmental-sound-classification-50/audio/esc10/data/'
source_base = './data/environmental-sound-classification-50/audio/'


for index, rows in df.iterrows():
    filename = rows[0]
    category = rows[3]
    esc10 = rows[4]
    #print(f'index={index}, filename={rows[0]}, category={rows[3]}, esc10={esc10}')
    target_dir = target_base + category
    source_file = source_base + filename
    target_file = target_dir + '/' + filename
    #print(f'target_dir={target_dir}, source file={source_path}')
    os.makedirs(target_dir, exist_ok=True)
    # get or create a new dir
    copyfile(source_file, target_file)
    # data augmentation, adjust db level in each file
    wave, sr = librosa.load(source_file, mono=True, sr=None)
    sound = random_gain(24)(wave).astype(np.float32)
    # write this new sound file to target directory. we will add prefix gain_ to the file
    target_gain_file = target_dir + '/' + 'gain_' + filename
    librosa.output.write_wav(target_gain_file, sound, sr)
    
    if esc10:
        target_esc10_dir = target_esc10_base + category
        #source_file = source_base + filename
        target_esc10_file = target_esc10_dir + '/' + filename
        #print(f'esc10={esc10}, target_esc10_dir={target_esc10_dir}, target_esc10_file={target_esc10_file}, category={category}, source_file={source_file}')
        os.makedirs(target_esc10_dir, exist_ok=True)
        # get or create a new dir
        copyfile(source_file, target_esc10_file)
        
        # data augmentation, adjust db level in each file
        wave, sr = librosa.load(source_file, mono=True, sr=None)
        sound = random_gain(24)(wave).astype(np.float32)
        # write this new sound file to target directory. we will add prefix gain_ to the file
        target_esc10_gain_file = target_esc10_dir + '/' + 'gain_' + filename
        librosa.output.write_wav(target_esc10_gain_file, sound, sr)

# %% [markdown]
# # Visualizing Sound
# <a id="visualization"></a>
#
# There are two theories of a human hearing - place ( https://en.wikipedia.org/wiki/Place_theory_(hearing) (frequency-based) and temporal (https://en.wikipedia.org/wiki/Temporal_theory_(hearing) )
# In speech recognition, I see two main tendencies - to input [spectrogram](https://en.wikipedia.org/wiki/Spectrogram) (frequencies), and more sophisticated features MFCC - Mel-Frequency Cepstral Coefficients, PLP. You rarely work with raw, temporal data.
#
# Let's listen to and visualize sample recordings from each category!
#
# ## Wave and spectrogram:
# <a id="waveandspectrogram"></a>
#
# Lets play a few samples:

# %%
audio_files = ['crickets/5-216216-A-13.wav', 'door_wood_creaks/5-191497-A-33.wav', 
              'cat/5-259169-A-5.wav'
              ]

# %%
path = './data//environmental-sound-classification-50/audio/data/'
for filename in audio_files:
    print(f'filename={filename}')
    filepath = path + filename
    samples,sample_rate = librosa.load(filepath)
    ipd.display(ipd.Audio(samples, rate=sample_rate))
# Out:
# filename=crickets/5-216216-A-13.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# filename=door_wood_creaks/5-191497-A-33.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# filename=cat/5-259169-A-5.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def log_specgram(audio, sample_rate=16000, window_size=20,
                 step_size=10, eps=1e-10):
    if audio.ndim > 1 : #ignore channels  2+
        audio = audio[:,0]
    nperseg = int(round(window_size * sample_rate / 1e3))
    noverlap = int(round(step_size * sample_rate / 1e3)) 
    freqs, times, spec = signal.spectrogram(audio,
                                    fs=sample_rate,
                                    window='hann',
                                    nperseg=nperseg,
                                    noverlap=noverlap,
                                    detrend=False)
    return freqs, times, np.log(spec.T.astype(np.float32) + eps)
#return freqs, times, np.log(spec.T.astype(np.float32) + eps)

# %%
def plot_spectrogram(samples, sample_rate, filename):
    freqs, times, spectrogram = log_specgram(samples, sample_rate)
    fig = plt.figure(figsize=(14, 8))
    ax1 = fig.add_subplot(211)
    ax1.set_title('Raw wave of ' + filename)
    ax1.set_ylabel('Amplitude')
    ax1.plot(np.linspace(0, len(samples)/sample_rate, len(samples)), samples)
    
    ax2 = fig.add_subplot(212)
    ax2.imshow(spectrogram.T, aspect='auto', origin='lower', 
           extent=[times.min(), times.max(), freqs.min(), freqs.max()])
    ax2.set_yticks(freqs[::16])
    ax2.set_xticks(times[::16])
    ax2.set_title('Spectrogram of ' + filename)
    ax2.set_ylabel('Freqs in Hz')
    ax2.set_xlabel('Seconds')
    first_part = filename.split('/')
    png_file = first_part[0] + '.png'
    plt.savefig(png_file)

# %% [markdown]
# ## Spectrogram shows the frequency range on y-axis with time. Several type of sounds sounds show steady frequency content between 0-11 KHz. Check the spectrograms out.

# %%
audio_files = ['crickets/5-216216-A-13.wav', 'door_wood_creaks/5-191497-A-33.wav', 
              'cat/5-259169-A-5.wav', 
               'chainsaw/5-222524-A-41.wav', 'vacuum_cleaner/5-263902-A-36.wav'
              ]

# %%
path = '/Users/guptafamily/Downloads/environmental-sound-classification-50/audio/data/'
for filename in audio_files:
    filepath = path + filename
    samples, sample_rate = librosa.load(filepath)
    #print(samples.shape)
    #print(f"sample rate ={sample_rate}, sample length = {len(samples)} ")
    plot_spectrogram (samples, sample_rate, filename)

# %% [markdown]
# ## Lets also plot the FFT to see the magnitude of the frequency, alongwith the frequency range. FFT confirms the findings of spectrogram and gives us dominant frequencies by looking at the y-axis.

# %%
def custom_fft(y, fs):
    T = 1.0 / fs
    N = y.shape[0]
    yf = fft(y)
    xf = np.linspace(0.0, 1.0/(2.0*T), N//2)
    vals = 2.0/N * np.abs(yf[0:N//2])  # FFT is simmetrical, so we take just the first half
    # FFT is also complex, to we take just the real part (abs)
    return xf, vals

# %%
def plot_fft(samples, sample_rate, filename):
    xf, vals = custom_fft(samples, sample_rate)
    plt.figure(figsize=(12, 4))
    plt.title('FFT of recording sampled with ' + str(sample_rate) + ' Hz' + ' for ' + filename)
    plt.plot(xf, vals)
    plt.xlabel('Frequency')
    plt.grid()
    plt.show()

# %%
#audio_files = ['crickets/5-216216-A-13.wav', 'door_wood_creaks/5-191497-A-33.wav', 
#              'cat/5-259169-A-5.wav', 'siren/5-184323-A-42.wav', 'sea_waves/5-219379-C-11.wav',
#               'rooster/5-234879-B-1.wav', 'sneezing/5-221593-A-21.wav', 'clock_tick/5-235671-A-38.wav',
#               'washing_machine/5-260875-A-35.wav', 'pig/5-127990-A-2.wav', 'toilet_flush/5-202540-A-18.wav',
#               'snoring/5-249748-A-28.wav', 'glass_breaking/5-260434-A-39.wav', 'coughing/5-251489-A-24.wav',
#               'hand_saw/5-253101-C-49.wav', 'crying_baby/5-198411-G-20.wav', 'breathing/5-261464-A-23.wav',
#               'engine/5-243783-A-44.wav', 'hen/5-263831-B-6.wav', 'laughing/5-263775-B-26.wav', 'insects/5-233787-A-7.wav',
#               'rain/5-203739-A-10.wav', 'drinking_sipping/5-259640-A-29.wav', 'helicopter/5-220955-A-40.wav',
#               'crackling_fire/5-215658-B-12.wav', 'car_horn/5-180156-C-43.wav', 'brushing_teeth/5-238938-A-27.wav', 
#               'cow/5-253085-B-3.wav', 'frog/5-237499-A-4.wav', 'footsteps/5-51149-A-25.wav', 'wind/5-217186-C-16.wav',
#               'keyboard_typing/5-244178-A-32.wav', 'clock_alarm/5-250629-A-37.wav', 'church_bells/5-219044-A-46.wav',
#               'water_drops/5-262641-A-15.wav', 'sheep/5-61635-A-8.wav', 'train/5-199284-B-45.wav', 
#               'pouring_water/5-215634-A-17.wav', 'mouse_click/5-244651-A-31.wav', 'airplane/5-251971-A-47.wav',
#               'chainsaw/5-222524-A-41.wav', 'fireworks/5-160614-H-48.wav', 'clapping/5-262957-A-22.wav',
#               'crow/5-261325-A-9.wav', 'can_opening/5-260011-A-34.wav', 'door_wood_knock/5-256512-A-30.wav',
#               'thunderstorm/5-195557-A-19.wav', 'vacuum_cleaner/5-263902-A-36.wav', 'chirping_birds/5-257839-A-14.wav',
#               'dog/5-9032-A-0.wav'
#              ]

audio_files = ['crickets/5-216216-A-13.wav', 'door_wood_creaks/5-191497-A-33.wav', 
              'cat/5-259169-A-5.wav', 
               'chainsaw/5-222524-A-41.wav', 'vacuum_cleaner/5-263902-A-36.wav'
              ]

# %%
path = './data/environmental-sound-classification-50/audio/data/'
for filename in audio_files:
    filepath = path + filename
    samples, sample_rate = librosa.load(filepath)
    print(f'filename={filename}, sample rate={sample_rate}')
    plot_fft (samples, sample_rate, filename)
# Out:
# filename=crickets/5-216216-A-13.wav, sample rate=22050
# filename=door_wood_creaks/5-191497-A-33.wav, sample rate=22050
# filename=cat/5-259169-A-5.wav, sample rate=22050
# filename=chainsaw/5-222524-A-41.wav, sample rate=22050
# filename=vacuum_cleaner/5-263902-A-36.wav, sample rate=22050

# %% [markdown]
# ## Finally lets plot the MFCC, delta MFCC and delta2 MFCC

# %%
def plot_mfcc (filename):
    
    #audio_path = '/Users/guptafamily/Downloads/environmental-sound-classification-50/audio/' + filename
    audio_path = './data/environmental-sound-classification-50/audio/data/' + filename
    
    y, sr = librosa.load(audio_path)
    # Let's make and display a mel-scaled power (energy-squared) spectrogram
    S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128)
    # Convert to log scale (dB). We'll use the peak power (max) as reference.
    log_S = librosa.power_to_db(S, ref=np.max)
    
    # Put a descriptive title on the plot
    #plt.title('mel power spectrogram')
    
    # draw a color bar
    #plt.colorbar(format='%+02.0f dB')
    
    # Next, we'll extract the top 39 Mel-frequency cepstral coefficients (MFCCs)
    mfcc        = librosa.feature.mfcc(S=log_S, n_mfcc=39)
    #print(f'mfcc shape = {mfcc.shape}')
    
    # Let's pad on the first and second deltas while we're at it
    delta_mfcc  = librosa.feature.delta(mfcc)
    delta2_mfcc = librosa.feature.delta(mfcc, order=2)
    
    # How do they look?  We'll show each in its own subplot
    plt.figure(figsize=(12, 6))
    
    title = "MFCC of " + filename
    plt.subplot(3,1,1)
    librosa.display.specshow(mfcc)
    plt.ylabel('MFCC')
    plt.colorbar()
    plt.title(title)
    
    
    plt.subplot(3,1,2)
    librosa.display.specshow(delta_mfcc)
    plt.ylabel('MFCC-$\Delta$')
    plt.colorbar()
    
    plt.subplot(3,1,3)
    librosa.display.specshow(delta2_mfcc, sr=sr, x_axis='time')
    plt.ylabel('MFCC-$\Delta^2$')
    plt.colorbar()
    
    plt.tight_layout()
    
    # For future use, we'll stack these together into one matrix
    M = np.vstack([mfcc, delta_mfcc, delta2_mfcc])

# Make a new figure
#plt.figure(figsize=(12,4))

# Display the spectrogram on a mel scale
# sample rate and hop length parameters are used to render the time axis
#librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')


# Make the figure layout compact
#plt.tight_layout()

# %%
audio_files = ['crickets/5-216216-A-13.wav', 'door_wood_creaks/5-191497-A-33.wav', 
              'cat/5-259169-A-5.wav', 
               'chainsaw/5-222524-A-41.wav', 'vacuum_cleaner/5-263902-A-36.wav'
              ]

# %%
#audio_path = './data/environmental-sound-classification-50/audio/data/'
for filename in audio_files:
    #samples, sample_rate = librosa.load(str(audio_path)+filename)
    #print(f'filename={filename}, sample rate={sample_rate}')
    plot_mfcc (filename)

# %% [markdown]
# ### The data set is not too large. 40 samples for each sound, plus another 40 augmented samples with +-6 db variation on original sample for each sound. Total of 4000 (80x50) samples. We will store this data in numpy array

# %%
#%load_ext autoreload
#%autoreload 2

#from preprocess import *
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.utils import to_categorical
from scipy.io import wavfile
import IPython.display as ipd

# Second dimension of the feature is dim2
feature_dim_2 = 144

# Save data to array file first
save_data_to_array(max_len=feature_dim_2)
# Out:
# Saving vectors of label - 'cat':   5%|▌         | 4/80 [00:00<00:01, 38.49it/s]
# labels=['cat', 'chainsaw', 'siren', 'clock_tick', 'can_opening', 'sneezing', 'pig', 'pouring_water', 'rain', 'church_bells', 'mouse_click', 'toilet_flush', 'car_horn', 'dog', 'vacuum_cleaner', 'chirping_birds', 'crackling_fire', 'breathing', 'crying_baby', 'sheep', 'glass_breaking', 'fireworks', 'crow', 'wind', 'helicopter', 'keyboard_typing', 'snoring', 'laughing', 'clapping', 'hen', 'airplane', 'sea_waves', 'footsteps', 'insects', 'train', 'water_drops', 'rooster', 'washing_machine', 'crickets', 'frog', 'coughing', 'hand_saw', 'door_wood_creaks', 'clock_alarm', 'drinking_sipping', 'door_wood_knock', 'brushing_teeth', 'engine', 'thunderstorm', 'cow']
# Saving vectors of label - 'cat': 100%|██████████| 80/80 [00:01<00:00, 56.59it/s]
# Saving vectors of label - 'chainsaw': 100%|██████████| 80/80 [00:01<00:00, 66.62it/s]
# Saving vectors of label - 'siren': 100%|██████████| 80/80 [00:01<00:00, 68.01it/s]
# Saving vectors of label - 'clock_tick': 100%|██████████| 80/80 [00:01<00:00, 68.46it/s]
# Saving vectors of label - 'can_opening': 100%|██████████| 80/80 [00:01<00:00, 69.23it/s]
# Saving vectors of label - 'sneezing': 100%|██████████| 80/80 [00:01<00:00, 68.39it/s]
# Saving vectors of label - 'pig': 100%|██████████| 80/80 [00:01<00:00, 67.83it/s]
# Saving vectors of label - 'pouring_water': 100%|██████████| 80/80 [00:01<00:00, 66.54it/s]
# Saving vectors of label - 'rain': 100%|██████████| 80/80 [00:01<00:00, 66.47it/s]
# Saving vectors of label - 'church_bells': 100%|██████████| 80/80 [00:01<00:00, 69.28it/s]
# Saving vectors of label - 'mouse_click': 100%|██████████| 80/80 [00:01<00:00, 68.47it/s]
# Saving vectors of label - 'toilet_flush': 100%|██████████| 80/80 [00:01<00:00, 68.17it/s]
# Saving vectors of label - 'car_horn': 100%|██████████| 80/80 [00:01<00:00, 68.16it/s]
# Saving vectors of label - 'dog': 100%|██████████| 80/80 [00:01<00:00, 66.59it/s]
# Saving vectors of label - 'vacuum_cleaner': 100%|██████████| 80/80 [00:01<00:00, 68.80it/s]
# Saving vectors of label - 'chirping_birds': 100%|██████████| 80/80 [00:01<00:00, 69.66it/s]
# Saving vectors of label - 'crackling_fire': 100%|██████████| 80/80 [00:01<00:00, 68.06it/s]
# Saving vectors of label - 'breathing': 100%|██████████| 80/80 [00:01<00:00, 66.19it/s]
# Saving vectors of label - 'crying_baby': 100%|██████████| 80/80 [00:01<00:00, 68.42it/s]
# Saving vectors of label - 'sheep': 100%|██████████| 80/80 [00:01<00:00, 68.44it/s]
# Saving vectors of label - 'glass_breaking': 100%|██████████| 80/80 [00:01<00:00, 68.11it/s]
# Saving vectors of label - 'fireworks': 100%|██████████| 80/80 [00:01<00:00, 67.64it/s]
# Saving vectors of label - 'crow': 100%|██████████| 80/80 [00:01<00:00, 67.21it/s]
# Saving vectors of label - 'wind': 100%|██████████| 80/80 [00:01<00:00, 66.15it/s]
# Saving vectors of label - 'helicopter': 100%|██████████| 80/80 [00:01<00:00, 67.45it/s]
# Saving vectors of label - 'keyboard_typing': 100%|██████████| 80/80 [00:01<00:00, 65.18it/s]
# Saving vectors of label - 'snoring': 100%|██████████| 80/80 [00:01<00:00, 66.42it/s]
# Saving vectors of label - 'laughing': 100%|██████████| 80/80 [00:01<00:00, 64.22it/s]
# Saving vectors of label - 'clapping': 100%|██████████| 80/80 [00:01<00:00, 62.46it/s]
# Saving vectors of label - 'hen': 100%|██████████| 80/80 [00:01<00:00, 64.63it/s]
# Saving vectors of label - 'airplane': 100%|██████████| 80/80 [00:01<00:00, 65.42it/s]
# Saving vectors of label - 'sea_waves': 100%|██████████| 80/80 [00:01<00:00, 66.88it/s]
# Saving vectors of label - 'footsteps': 100%|██████████| 80/80 [00:01<00:00, 65.71it/s]
# Saving vectors of label - 'insects': 100%|██████████| 80/80 [00:01<00:00, 66.01it/s]
# Saving vectors of label - 'train': 100%|██████████| 80/80 [00:01<00:00, 67.20it/s]
# Saving vectors of label - 'water_drops': 100%|██████████| 80/80 [00:01<00:00, 66.64it/s]
# Saving vectors of label - 'rooster': 100%|██████████| 80/80 [00:01<00:00, 61.87it/s]
# Saving vectors of label - 'washing_machine': 100%|██████████| 80/80 [00:01<00:00, 63.97it/s]
# Saving vectors of label - 'crickets': 100%|██████████| 80/80 [00:01<00:00, 65.48it/s]
# Saving vectors of label - 'frog': 100%|██████████| 80/80 [00:01<00:00, 63.32it/s]
# Saving vectors of label - 'coughing': 100%|██████████| 80/80 [00:01<00:00, 60.25it/s]
# Saving vectors of label - 'hand_saw': 100%|██████████| 80/80 [00:01<00:00, 60.96it/s]
# Saving vectors of label - 'door_wood_creaks': 100%|██████████| 80/80 [00:01<00:00, 59.21it/s]
# Saving vectors of label - 'clock_alarm': 100%|██████████| 80/80 [00:01<00:00, 64.40it/s]
# Saving vectors of label - 'drinking_sipping': 100%|██████████| 80/80 [00:01<00:00, 66.60it/s]
# Saving vectors of label - 'door_wood_knock': 100%|██████████| 80/80 [00:01<00:00, 66.31it/s]
# Saving vectors of label - 'brushing_teeth': 100%|██████████| 80/80 [00:01<00:00, 65.46it/s]
# Saving vectors of label - 'engine': 100%|██████████| 80/80 [00:01<00:00, 66.74it/s]
# Saving vectors of label - 'thunderstorm': 100%|██████████| 80/80 [00:01<00:00, 62.96it/s]
# Saving vectors of label - 'cow': 100%|██████████| 80/80 [00:01<00:00, 57.31it/s]

# %% [markdown]
# ## There are 39 mfcc features and each feature is 144 vectors long. We are using 90 (train)-10(test) split

# %%
X_train, X_test, y_train, y_test = get_train_test()

feature_dim_1 = 39
channel = 1
epochs = 50
batch_size = 100
verbose = 1
num_classes = 50

# Reshaping to perform 2D convolution
X_train = X_train.reshape(X_train.shape[0], feature_dim_1, feature_dim_2, channel)
X_test = X_test.reshape(X_test.shape[0], feature_dim_1, feature_dim_2, channel)

y_train_hot = to_categorical(y_train)
y_test_hot = to_categorical(y_test)

# %%
print(X_train.shape, X_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (3600, 39, 144, 1) (400, 39, 144, 1)
# (3600,) (400,)

# %% [markdown]
# ## Model is the same as in our Assignment 12 with 50 classes. 3 convolutional layers with downsampling and dropout, followed by dense layers and dropout.

# %%
def get_model():
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(2, 2), activation='relu', input_shape=(feature_dim_1, feature_dim_2, channel)))
    model.add(Conv2D(48, kernel_size=(2, 2), activation='relu'))
    model.add(Conv2D(120, kernel_size=(2, 2), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss=tensorflow.keras.losses.categorical_crossentropy,
                  optimizer=tensorflow.keras.optimizers.Adadelta(),
                  metrics=['accuracy'])
    return model

# Predicts one sample
def predict(filepath, model):
    sample = wav2mfcc(filepath)
    sample_reshaped = sample.reshape(1, feature_dim_1, feature_dim_2, channel)
    return get_labels()[0][
            np.argmax(model.predict(sample_reshaped))
    ]

# %%
model = get_model()
# model.fit(X_train, y_train_hot, batch_size=batch_size, epochs=epochs, verbose=verbose, validation_data=(X_test, y_test_hot))
hist = model.fit(X_train, y_train_hot, batch_size=batch_size, epochs=epochs, verbose=verbose, validation_data=(X_test, y_test_hot))
# Out:
# Train on 3600 samples, validate on 400 samples
# Epoch 1/50
# 3600/3600 [==============================] - 76s 21ms/step - loss: 12.7039 - acc: 0.0236 - val_loss: 3.8982 - val_acc: 0.0250
# Epoch 2/50
# 3600/3600 [==============================] - 73s 20ms/step - loss: 3.8397 - acc: 0.0497 - val_loss: 3.6948 - val_acc: 0.0850
# Epoch 3/50
# 3600/3600 [==============================] - 73s 20ms/step - loss: 3.6103 - acc: 0.0989 - val_loss: 3.2111 - val_acc: 0.2125
# Epoch 4/50
# 3600/3600 [==============================] - 74s 20ms/step - loss: 3.2423 - acc: 0.1772 - val_loss: 2.4868 - val_acc: 0.4550
# Epoch 5/50
# 3600/3600 [==============================] - 74s 20ms/step - loss: 2.6037 - acc: 0.3189 - val_loss: 2.1430 - val_acc: 0.5275
# Epoch 6/50
# 3600/3600 [==============================] - 73s 20ms/step - loss: 1.9205 - acc: 0.4750 - val_loss: 1.6009 - val_acc: 0.6675
# Epoch 7/50
# 3600/3600 [==============================] - 73s 20ms/step - loss: 1.4302 - acc: 0.6008 - val_loss: 1.0212 - val_acc: 0.8275
# Epoch 8/50
# 3600/3600 [==============================] - 74s 20ms/step - loss: 1.0666 - acc: 0.6850 - val_loss: 0.8487 - val_acc: 0.8425
# Epoch 9/50
# 3600/3600 [==============================] - 73s 20ms/step - loss: 0.8190 - acc: 0.7631 - val_loss: 0.6102 - val_acc: 0.8800
# Epoch 10/50
# 3600/3600 [==============================] - 73s 20ms/step - loss: 0.7470 - acc: 0.7850 - val_loss: 0.4298 - val_acc: 0.9200
# Epoch 11/50
# 3600/3600 [==============================] - 74s 21ms/step - loss: 0.5968 - acc: 0.8256 - val_loss: 0.4044 - val_acc: 0.9175
# Epoch 12/50
# 3600/3600 [==============================] - 72s 20ms/step - loss: 0.5636 - acc: 0.8342 - val_loss: 0.3602 - val_acc: 0.9225
# Epoch 13/50
# 3600/3600 [==============================] - 1203s 334ms/step - loss: 0.4823 - acc: 0.8583 - val_loss: 0.3711 - val_acc: 0.9225
# Epoch 14/50
# 3600/3600 [==============================] - 74s 21ms/step - loss: 0.3919 - acc: 0.8817 - val_loss: 0.4194 - val_acc: 0.9125
# Epoch 15/50
# 3600/3600 [==============================] - 76s 21ms/step - loss: 0.3569 - acc: 0.8925 - val_loss: 0.3441 - val_acc: 0.9225
# Epoch 16/50
# 3600/3600 [==============================] - 74s 21ms/step - loss: 0.3573 - acc: 0.8958 - val_loss: 0.3719 - val_acc: 0.9225
# Epoch 17/50
# 3600/3600 [==============================] - 74s 21ms/step - loss: 0.3500 - acc: 0.8914 - val_loss: 0.3170 - val_acc: 0.9275
# Epoch 18/50
# 3600/3600 [==============================] - 75s 21ms/step - loss: 0.3252 - acc: 0.9064 - val_loss: 0.3522 - val_acc: 0.9350
# Epoch 19/50
# 3600/3600 [==============================] - 73s 20ms/step - loss: 0.2922 - acc: 0.9133 - val_loss: 0.3620 - val_acc: 0.9250
# Epoch 20/50
# 3600/3600 [==============================] - 73s 20ms/step - loss: 0.2806 - acc: 0.9164 - val_loss: 0.3450 - val_acc: 0.9200
# Epoch 21/50
# 3600/3600 [==============================] - 76s 21ms/step - loss: 0.2465 - acc: 0.9233 - val_loss: 0.3652 - val_acc: 0.9175
# Epoch 22/50
# 3600/3600 [==============================] - 81s 22ms/step - loss: 0.2315 - acc: 0.9267 - val_loss: 0.3105 - val_acc: 0.9375
# Epoch 23/50
# 3600/3600 [==============================] - 77s 21ms/step - loss: 0.2262 - acc: 0.9333 - val_loss: 0.3432 - val_acc: 0.9250
# Epoch 24/50
# 3600/3600 [==============================] - 73s 20ms/step - loss: 0.2250 - acc: 0.9311 - val_loss: 0.3043 - val_acc: 0.9375
# Epoch 25/50
# 3600/3600 [==============================] - 76s 21ms/step - loss: 0.2287 - acc: 0.9328 - val_loss: 0.3197 - val_acc: 0.9200
# Epoch 26/50
# 3600/3600 [==============================] - 77s 21ms/step - loss: 0.2089 - acc: 0.9381 - val_loss: 0.3848 - val_acc: 0.9275
# Epoch 27/50
# 3600/3600 [==============================] - 79s 22ms/step - loss: 0.1857 - acc: 0.9456 - val_loss: 0.2876 - val_acc: 0.9325
# Epoch 28/50
# 3600/3600 [==============================] - 76s 21ms/step - loss: 0.1912 - acc: 0.9431 - val_loss: 0.3409 - val_acc: 0.9175
# Epoch 29/50
# 3600/3600 [==============================] - 76s 21ms/step - loss: 0.1730 - acc: 0.9467 - val_loss: 0.2992 - val_acc: 0.9300
# Epoch 30/50
# 3600/3600 [==============================] - 75s 21ms/step - loss: 0.1642 - acc: 0.9489 - val_loss: 0.3155 - val_acc: 0.9325
# Epoch 31/50
# 3600/3600 [==============================] - 74s 21ms/step - loss: 0.1607 - acc: 0.9508 - val_loss: 0.3777 - val_acc: 0.9250
# Epoch 32/50
# 3600/3600 [==============================] - 74s 21ms/step - loss: 0.1372 - acc: 0.9586 - val_loss: 0.3362 - val_acc: 0.9325
# Epoch 33/50
# 3600/3600 [==============================] - 75s 21ms/step - loss: 0.1681 - acc: 0.9489 - val_loss: 0.3348 - val_acc: 0.9425
# Epoch 34/50
# 3600/3600 [==============================] - 74s 20ms/step - loss: 0.1473 - acc: 0.9522 - val_loss: 0.3653 - val_acc: 0.9300
# Epoch 35/50
# 3600/3600 [==============================] - 75s 21ms/step - loss: 0.1576 - acc: 0.9522 - val_loss: 0.2586 - val_acc: 0.9425
# Epoch 36/50
# 3600/3600 [==============================] - 74s 21ms/step - loss: 0.1504 - acc: 0.9561 - val_loss: 0.3030 - val_acc: 0.9375
# Epoch 37/50
# 3600/3600 [==============================] - 74s 21ms/step - loss: 0.1613 - acc: 0.9539 - val_loss: 0.2893 - val_acc: 0.9375
# Epoch 38/50
# 3600/3600 [==============================] - 75s 21ms/step - loss: 0.1521 - acc: 0.9542 - val_loss: 0.3186 - val_acc: 0.9350
# Epoch 39/50
# 3600/3600 [==============================] - 74s 21ms/step - loss: 0.1521 - acc: 0.9564 - val_loss: 0.3566 - val_acc: 0.9300
# Epoch 40/50
# 3600/3600 [==============================] - 74s 21ms/step - loss: 0.1237 - acc: 0.9642 - val_loss: 0.2954 - val_acc: 0.9375
# Epoch 41/50
# 3600/3600 [==============================] - 75s 21ms/step - loss: 0.1201 - acc: 0.9614 - val_loss: 0.3252 - val_acc: 0.9350
# Epoch 42/50
# 3600/3600 [==============================] - 75s 21ms/step - loss: 0.1087 - acc: 0.9667 - val_loss: 0.3841 - val_acc: 0.9325
# Epoch 43/50
# 3600/3600 [==============================] - 75s 21ms/step - loss: 0.1132 - acc: 0.9647 - val_loss: 0.3693 - val_acc: 0.9275
# Epoch 44/50
# 3600/3600 [==============================] - 77s 22ms/step - loss: 0.1056 - acc: 0.9672 - val_loss: 0.4239 - val_acc: 0.9425
# Epoch 45/50
# 3600/3600 [==============================] - 77s 21ms/step - loss: 0.1383 - acc: 0.9581 - val_loss: 0.3572 - val_acc: 0.9350
# Epoch 46/50
# 3600/3600 [==============================] - 84s 23ms/step - loss: 0.0963 - acc: 0.9692 - val_loss: 0.3754 - val_acc: 0.9200
# Epoch 47/50
# 3600/3600 [==============================] - 90s 25ms/step - loss: 0.1136 - acc: 0.9622 - val_loss: 0.3858 - val_acc: 0.9400
# Epoch 48/50
# 3600/3600 [==============================] - 76s 21ms/step - loss: 0.1058 - acc: 0.9681 - val_loss: 0.4054 - val_acc: 0.9425
# Epoch 49/50
# 3600/3600 [==============================] - 77s 21ms/step - loss: 0.1007 - acc: 0.9683 - val_loss: 0.3518 - val_acc: 0.9300
# Epoch 50/50
# 3600/3600 [==============================] - 78s 22ms/step - loss: 0.1122 - acc: 0.9653 - val_loss: 0.3319 - val_acc: 0.9400

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  

plt.figure(figsize=(12,8))
plt.plot(hist.history['val_acc'], label='Accuracy')
plt.title("Final accuracy on validation data (50 epochs): {:.3%}".format(hist.history['val_acc'][-1:][0]))
plt.legend(loc=2)
_ = plt.show()
plt.savefig("acc.png")

# %% [markdown]
# ### Make Prediction
#
# Let us see whether trained network could properly classify a random sampling of sounds. The results below look good.

# %%
audio_files = ['crickets/5-216216-A-13.wav', 'door_wood_creaks/5-191497-A-33.wav', 
              'cat/5-259169-A-5.wav', 'siren/5-184323-A-42.wav', 'sea_waves/5-219379-C-11.wav',
               'rooster/5-234879-B-1.wav', 'sneezing/5-221593-A-21.wav', 'clock_tick/5-235671-A-38.wav',
               'washing_machine/5-260875-A-35.wav', 'pig/5-127990-A-2.wav', 'toilet_flush/5-202540-A-18.wav',
               'snoring/5-249748-A-28.wav', 'glass_breaking/5-260434-A-39.wav', 'coughing/5-251489-A-24.wav',
               'hand_saw/5-253101-C-49.wav', 'crying_baby/5-198411-G-20.wav', 'breathing/5-261464-A-23.wav',
               'engine/5-243783-A-44.wav', 'hen/5-263831-B-6.wav', 'laughing/5-263775-B-26.wav', 'insects/5-233787-A-7.wav',
               'rain/5-203739-A-10.wav', 'drinking_sipping/5-259640-A-29.wav', 'helicopter/5-220955-A-40.wav',
               'crackling_fire/5-215658-B-12.wav', 'car_horn/5-180156-C-43.wav', 'brushing_teeth/5-238938-A-27.wav', 
               'cow/5-253085-B-3.wav', 'frog/5-237499-A-4.wav', 'footsteps/5-51149-A-25.wav', 'wind/5-217186-C-16.wav',
               'keyboard_typing/5-244178-A-32.wav', 'clock_alarm/5-250629-A-37.wav', 'church_bells/5-219044-A-46.wav',
               'water_drops/5-262641-A-15.wav', 'sheep/5-61635-A-8.wav', 'train/5-199284-B-45.wav', 
               'pouring_water/5-215634-A-17.wav', 'mouse_click/5-244651-A-31.wav', 'airplane/5-251971-A-47.wav',
               'chainsaw/5-222524-A-41.wav', 'fireworks/5-160614-H-48.wav', 'clapping/5-262957-A-22.wav',
               'crow/5-261325-A-9.wav', 'can_opening/5-260011-A-34.wav', 'door_wood_knock/5-256512-A-30.wav',
               'thunderstorm/5-195557-A-19.wav', 'vacuum_cleaner/5-263902-A-36.wav', 'chirping_birds/5-257839-A-14.wav',
               'dog/5-9032-A-0.wav'
              ]

# %%
# Predicts one sample
def predict2(filepath, model):
    sample = wav2mfcc(filepath)
    #print(f'sample shape={sample.shape}')
    sample_reshaped = sample.reshape(1, feature_dim_1, feature_dim_2, channel)
    return get_labels()[0][
            np.argmax(model.predict(sample_reshaped))
    ]

#print(predict('./data/cat/6ac35824_nohash_0.wav', model=model))
path = './data/environmental-sound-classification-50/audio/data/'
for filename in audio_files:
    print(f'filename={filename}')
    filepath = path + filename
    prediction = predict2(filepath, model=model)
    print(f'prediction={prediction}')
# Out:
# filename=crickets/5-216216-A-13.wav
# prediction=crickets
# filename=door_wood_creaks/5-191497-A-33.wav
# prediction=door_wood_creaks
# filename=cat/5-259169-A-5.wav
# prediction=cat
# filename=siren/5-184323-A-42.wav
# prediction=siren
# filename=sea_waves/5-219379-C-11.wav
# prediction=sea_waves
# filename=rooster/5-234879-B-1.wav
# prediction=rooster
# filename=sneezing/5-221593-A-21.wav
# prediction=sneezing
# filename=clock_tick/5-235671-A-38.wav
# prediction=clock_tick
# filename=washing_machine/5-260875-A-35.wav
# prediction=washing_machine
# filename=pig/5-127990-A-2.wav
# prediction=pig
# filename=toilet_flush/5-202540-A-18.wav
# prediction=toilet_flush
# filename=snoring/5-249748-A-28.wav
# prediction=snoring
# filename=glass_breaking/5-260434-A-39.wav
# prediction=glass_breaking
# filename=coughing/5-251489-A-24.wav
# prediction=coughing
# filename=hand_saw/5-253101-C-49.wav
# prediction=hand_saw
# filename=crying_baby/5-198411-G-20.wav
# prediction=crying_baby
# filename=breathing/5-261464-A-23.wav
# prediction=breathing
# filename=engine/5-243783-A-44.wav
# prediction=engine
# filename=hen/5-263831-B-6.wav
# prediction=hen
# filename=laughing/5-263775-B-26.wav
# prediction=laughing
# filename=insects/5-233787-A-7.wav
# prediction=insects
# filename=rain/5-203739-A-10.wav
# prediction=rain
# filename=drinking_sipping/5-259640-A-29.wav
# prediction=drinking_sipping
# filename=helicopter/5-220955-A-40.wav
# prediction=helicopter
# filename=crackling_fire/5-215658-B-12.wav
# prediction=crackling_fire
# filename=car_horn/5-180156-C-43.wav
# prediction=crow
# filename=brushing_teeth/5-238938-A-27.wav
# prediction=brushing_teeth
# filename=cow/5-253085-B-3.wav
# prediction=cow
# filename=frog/5-237499-A-4.wav
# prediction=frog
# filename=footsteps/5-51149-A-25.wav
# prediction=footsteps
# filename=wind/5-217186-C-16.wav
# prediction=wind
# filename=keyboard_typing/5-244178-A-32.wav
# prediction=keyboard_typing
# filename=clock_alarm/5-250629-A-37.wav
# prediction=clock_alarm
# filename=church_bells/5-219044-A-46.wav
# prediction=church_bells
# filename=water_drops/5-262641-A-15.wav
# prediction=water_drops
# filename=sheep/5-61635-A-8.wav
# prediction=sheep
# filename=train/5-199284-B-45.wav
# prediction=train
# filename=pouring_water/5-215634-A-17.wav
# prediction=pouring_water
# filename=mouse_click/5-244651-A-31.wav
# prediction=mouse_click
# filename=airplane/5-251971-A-47.wav
# prediction=airplane
# filename=chainsaw/5-222524-A-41.wav
# prediction=chainsaw
# filename=fireworks/5-160614-H-48.wav
# prediction=fireworks
# filename=clapping/5-262957-A-22.wav
# prediction=clapping
# filename=crow/5-261325-A-9.wav
# prediction=crow
# filename=can_opening/5-260011-A-34.wav
# prediction=can_opening
# filename=door_wood_knock/5-256512-A-30.wav
# prediction=door_wood_knock
# filename=thunderstorm/5-195557-A-19.wav
# prediction=thunderstorm
# filename=vacuum_cleaner/5-263902-A-36.wav
# prediction=vacuum_cleaner
# filename=chirping_birds/5-257839-A-14.wav
# prediction=chirping_birds
# filename=dog/5-9032-A-0.wav
# prediction=dog

# %% [markdown]
# # As a reference, lets run the model without data augmentation.

# %%
# read the csv file and place the sound samples under the correct label directoy 

csv_file = './data/environmental-sound-classification-50/esc50.csv'
df = pd.read_csv(csv_file)

# This routine creates a data directory under the audio directory and places the respective 
# .wav files under the correct labels
# example for "label' siren": './data/environmental-sound-classification-50/audio/data/siren/5-184323-A-42.wav'
# the data augmented files have a "gain" prefix. 
# Example: './data/environmental-sound-classification-50/audio/data/siren/gain_5-184323-A-42.wav'

target_base = './data/environmental-sound-classification-50/audio/data_notaugmented/'
source_base = './data/environmental-sound-classification-50/audio/'


for index, rows in df.iterrows():
    filename = rows[0]
    category = rows[3]
    esc10 = rows[4]
    target_dir = target_base + category
    source_file = source_base + filename
    target_file = target_dir + '/' + filename
    os.makedirs(target_dir, exist_ok=True)
    # get or create a new dir
    copyfile(source_file, target_file)

# %%
# Second dimension of the feature is dim2
feature_dim_2 = 144

# Save data to array file first
save_data_to_array('./data/environmental-sound-classification-50/audio/data_notaugmented/',max_len=feature_dim_2)
# Out:
# Saving vectors of label - 'cat':   5%|▌         | 2/40 [00:00<00:02, 17.82it/s]
# labels=['cat', 'chainsaw', 'siren', 'clock_tick', 'can_opening', 'sneezing', 'pig', 'pouring_water', 'rain', 'church_bells', 'mouse_click', 'toilet_flush', 'car_horn', 'dog', 'vacuum_cleaner', 'chirping_birds', 'crackling_fire', 'breathing', 'crying_baby', 'sheep', 'glass_breaking', 'fireworks', 'crow', 'wind', 'helicopter', 'keyboard_typing', 'snoring', 'laughing', 'clapping', 'hen', 'airplane', 'sea_waves', 'footsteps', 'insects', 'train', 'water_drops', 'rooster', 'washing_machine', 'crickets', 'frog', 'coughing', 'hand_saw', 'door_wood_creaks', 'clock_alarm', 'drinking_sipping', 'door_wood_knock', 'brushing_teeth', 'engine', 'thunderstorm', 'cow']
# Saving vectors of label - 'cat': 100%|██████████| 40/40 [00:00<00:00, 43.91it/s]
# Saving vectors of label - 'chainsaw': 100%|██████████| 40/40 [00:00<00:00, 63.32it/s]
# Saving vectors of label - 'siren': 100%|██████████| 40/40 [00:00<00:00, 61.33it/s]
# Saving vectors of label - 'clock_tick': 100%|██████████| 40/40 [00:00<00:00, 56.92it/s]
# Saving vectors of label - 'can_opening': 100%|██████████| 40/40 [00:00<00:00, 63.03it/s]
# Saving vectors of label - 'sneezing': 100%|██████████| 40/40 [00:00<00:00, 56.46it/s]
# Saving vectors of label - 'pig': 100%|██████████| 40/40 [00:00<00:00, 60.71it/s]
# Saving vectors of label - 'pouring_water': 100%|██████████| 40/40 [00:00<00:00, 60.11it/s]
# Saving vectors of label - 'rain': 100%|██████████| 40/40 [00:00<00:00, 58.48it/s]
# Saving vectors of label - 'church_bells': 100%|██████████| 40/40 [00:00<00:00, 64.50it/s]
# Saving vectors of label - 'mouse_click': 100%|██████████| 40/40 [00:00<00:00, 63.12it/s]
# Saving vectors of label - 'toilet_flush': 100%|██████████| 40/40 [00:00<00:00, 60.81it/s]
# Saving vectors of label - 'car_horn': 100%|██████████| 40/40 [00:00<00:00, 63.34it/s]
# Saving vectors of label - 'dog': 100%|██████████| 40/40 [00:00<00:00, 63.05it/s]
# Saving vectors of label - 'vacuum_cleaner': 100%|██████████| 40/40 [00:00<00:00, 60.50it/s]
# Saving vectors of label - 'chirping_birds': 100%|██████████| 40/40 [00:00<00:00, 61.11it/s]
# Saving vectors of label - 'crackling_fire': 100%|██████████| 40/40 [00:00<00:00, 60.34it/s]
# Saving vectors of label - 'breathing': 100%|██████████| 40/40 [00:00<00:00, 59.01it/s]
# Saving vectors of label - 'crying_baby': 100%|██████████| 40/40 [00:00<00:00, 64.11it/s]
# Saving vectors of label - 'sheep': 100%|██████████| 40/40 [00:00<00:00, 61.89it/s]
# Saving vectors of label - 'glass_breaking': 100%|██████████| 40/40 [00:00<00:00, 56.39it/s]
# Saving vectors of label - 'fireworks': 100%|██████████| 40/40 [00:00<00:00, 62.42it/s]
# Saving vectors of label - 'crow': 100%|██████████| 40/40 [00:00<00:00, 58.64it/s]
# Saving vectors of label - 'wind': 100%|██████████| 40/40 [00:00<00:00, 57.45it/s]
# Saving vectors of label - 'helicopter': 100%|██████████| 40/40 [00:00<00:00, 59.88it/s]
# Saving vectors of label - 'keyboard_typing': 100%|██████████| 40/40 [00:00<00:00, 56.33it/s]
# Saving vectors of label - 'snoring': 100%|██████████| 40/40 [00:00<00:00, 50.02it/s]
# Saving vectors of label - 'laughing': 100%|██████████| 40/40 [00:00<00:00, 54.09it/s]
# Saving vectors of label - 'clapping': 100%|██████████| 40/40 [00:00<00:00, 58.59it/s]
# Saving vectors of label - 'hen': 100%|██████████| 40/40 [00:00<00:00, 65.14it/s]
# Saving vectors of label - 'airplane': 100%|██████████| 40/40 [00:00<00:00, 58.71it/s]
# Saving vectors of label - 'sea_waves': 100%|██████████| 40/40 [00:00<00:00, 54.70it/s]
# Saving vectors of label - 'footsteps': 100%|██████████| 40/40 [00:00<00:00, 56.35it/s]
# Saving vectors of label - 'insects': 100%|██████████| 40/40 [00:00<00:00, 62.05it/s]
# Saving vectors of label - 'train': 100%|██████████| 40/40 [00:00<00:00, 45.28it/s]
# Saving vectors of label - 'water_drops': 100%|██████████| 40/40 [00:00<00:00, 44.45it/s]
# Saving vectors of label - 'rooster': 100%|██████████| 40/40 [00:00<00:00, 45.82it/s]
# Saving vectors of label - 'washing_machine': 100%|██████████| 40/40 [00:00<00:00, 66.10it/s]
# Saving vectors of label - 'crickets': 100%|██████████| 40/40 [00:00<00:00, 56.71it/s]
# Saving vectors of label - 'frog': 100%|██████████| 40/40 [00:00<00:00, 57.46it/s]
# Saving vectors of label - 'coughing': 100%|██████████| 40/40 [00:00<00:00, 67.92it/s]
# Saving vectors of label - 'hand_saw': 100%|██████████| 40/40 [00:00<00:00, 53.66it/s]
# Saving vectors of label - 'door_wood_creaks': 100%|██████████| 40/40 [00:00<00:00, 53.98it/s]
# Saving vectors of label - 'clock_alarm': 100%|██████████| 40/40 [00:00<00:00, 54.88it/s]
# Saving vectors of label - 'drinking_sipping': 100%|██████████| 40/40 [00:00<00:00, 65.72it/s]
# Saving vectors of label - 'door_wood_knock': 100%|██████████| 40/40 [00:00<00:00, 65.98it/s]
# Saving vectors of label - 'brushing_teeth': 100%|██████████| 40/40 [00:00<00:00, 63.69it/s]
# Saving vectors of label - 'engine': 100%|██████████| 40/40 [00:00<00:00, 60.28it/s]
# Saving vectors of label - 'thunderstorm': 100%|██████████| 40/40 [00:00<00:00, 58.24it/s]
# Saving vectors of label - 'cow': 100%|██████████| 40/40 [00:00<00:00, 57.87it/s]

# %%
X_train, X_test, y_train, y_test = get_train_test()

feature_dim_1 = 39
channel = 1
epochs = 50
batch_size = 100
verbose = 1
num_classes = 50

# Reshaping to perform 2D convolution
X_train = X_train.reshape(X_train.shape[0], feature_dim_1, feature_dim_2, channel)
X_test = X_test.reshape(X_test.shape[0], feature_dim_1, feature_dim_2, channel)

y_train_hot = to_categorical(y_train)
y_test_hot = to_categorical(y_test)

# %% [markdown]
# ### We now have 2000 samples. 1800 train samples, 200 test samples

# %%
print(X_train.shape, X_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (1800, 39, 144, 1) (200, 39, 144, 1)
# (1800,) (200,)

# %%
model = get_model()
# model.fit(X_train, y_train_hot, batch_size=batch_size, epochs=epochs, verbose=verbose, validation_data=(X_test, y_test_hot))
hist2 = model.fit(X_train, y_train_hot, batch_size=batch_size, epochs=epochs, verbose=verbose, validation_data=(X_test, y_test_hot))
# Out:
# Train on 1800 samples, validate on 200 samples
# Epoch 1/50
# 1800/1800 [==============================] - 39s 22ms/step - loss: 12.2055 - acc: 0.0217 - val_loss: 3.8920 - val_acc: 0.0450
# Epoch 2/50
# 1800/1800 [==============================] - 37s 21ms/step - loss: 3.9099 - acc: 0.0278 - val_loss: 3.8505 - val_acc: 0.0300
# Epoch 3/50
# 1800/1800 [==============================] - 37s 21ms/step - loss: 3.8597 - acc: 0.0472 - val_loss: 3.7374 - val_acc: 0.1300
# Epoch 4/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 3.7815 - acc: 0.0633 - val_loss: 3.7845 - val_acc: 0.0750
# Epoch 5/50
# 1800/1800 [==============================] - 37s 20ms/step - loss: 3.6300 - acc: 0.0944 - val_loss: 3.5095 - val_acc: 0.1800
# Epoch 6/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 3.4082 - acc: 0.1567 - val_loss: 3.3562 - val_acc: 0.2200
# Epoch 7/50
# 1800/1800 [==============================] - 37s 20ms/step - loss: 3.1409 - acc: 0.1933 - val_loss: 3.1329 - val_acc: 0.2900
# Epoch 8/50
# 1800/1800 [==============================] - 37s 20ms/step - loss: 2.8334 - acc: 0.2767 - val_loss: 2.9210 - val_acc: 0.3050
# Epoch 9/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 2.5367 - acc: 0.3294 - val_loss: 2.7586 - val_acc: 0.3150
# Epoch 10/50
# 1800/1800 [==============================] - 39s 22ms/step - loss: 2.1776 - acc: 0.4161 - val_loss: 2.6789 - val_acc: 0.3100
# Epoch 11/50
# 1800/1800 [==============================] - 45s 25ms/step - loss: 1.7688 - acc: 0.5161 - val_loss: 2.6433 - val_acc: 0.3300
# Epoch 12/50
# 1800/1800 [==============================] - 38s 21ms/step - loss: 1.4576 - acc: 0.5983 - val_loss: 2.3766 - val_acc: 0.3900
# Epoch 13/50
# 1800/1800 [==============================] - 38s 21ms/step - loss: 1.2942 - acc: 0.6339 - val_loss: 2.3822 - val_acc: 0.3600
# Epoch 14/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 1.0178 - acc: 0.7089 - val_loss: 2.3117 - val_acc: 0.3950
# Epoch 15/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.9292 - acc: 0.7322 - val_loss: 2.3780 - val_acc: 0.3850
# Epoch 16/50
# 1800/1800 [==============================] - 35s 19ms/step - loss: 0.7662 - acc: 0.7772 - val_loss: 2.3045 - val_acc: 0.4150
# Epoch 17/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.7152 - acc: 0.7950 - val_loss: 2.2892 - val_acc: 0.4350
# Epoch 18/50
# 1800/1800 [==============================] - 35s 20ms/step - loss: 0.6754 - acc: 0.8094 - val_loss: 2.2990 - val_acc: 0.4200
# Epoch 19/50
# 1800/1800 [==============================] - 35s 20ms/step - loss: 0.5641 - acc: 0.8356 - val_loss: 2.3095 - val_acc: 0.4400
# Epoch 20/50
# 1800/1800 [==============================] - 35s 20ms/step - loss: 0.5251 - acc: 0.8478 - val_loss: 2.4661 - val_acc: 0.3900
# Epoch 21/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.5128 - acc: 0.8544 - val_loss: 2.3875 - val_acc: 0.4300
# Epoch 22/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.4263 - acc: 0.8789 - val_loss: 2.3162 - val_acc: 0.4550
# Epoch 23/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.4309 - acc: 0.8717 - val_loss: 2.3376 - val_acc: 0.4250
# Epoch 24/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.3979 - acc: 0.8750 - val_loss: 2.2898 - val_acc: 0.4650
# Epoch 25/50
# 1800/1800 [==============================] - 35s 20ms/step - loss: 0.4021 - acc: 0.8900 - val_loss: 2.3298 - val_acc: 0.4200
# Epoch 26/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.4009 - acc: 0.8817 - val_loss: 2.3364 - val_acc: 0.4550
# Epoch 27/50
# 1800/1800 [==============================] - 35s 20ms/step - loss: 0.3395 - acc: 0.8944 - val_loss: 2.3599 - val_acc: 0.4550
# Epoch 28/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.3395 - acc: 0.9039 - val_loss: 2.3844 - val_acc: 0.4650
# Epoch 29/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.3278 - acc: 0.9094 - val_loss: 2.3846 - val_acc: 0.4300
# Epoch 30/50
# 1800/1800 [==============================] - 35s 20ms/step - loss: 0.3146 - acc: 0.9028 - val_loss: 2.4956 - val_acc: 0.4600
# Epoch 31/50
# 1800/1800 [==============================] - 37s 20ms/step - loss: 0.3223 - acc: 0.9122 - val_loss: 2.3612 - val_acc: 0.4650
# Epoch 32/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.2798 - acc: 0.9183 - val_loss: 2.4615 - val_acc: 0.4250
# Epoch 33/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.3215 - acc: 0.9039 - val_loss: 2.3454 - val_acc: 0.4200
# Epoch 34/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.2597 - acc: 0.9206 - val_loss: 2.3327 - val_acc: 0.4350
# Epoch 35/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.2531 - acc: 0.9161 - val_loss: 2.5513 - val_acc: 0.4250
# Epoch 36/50
# 1800/1800 [==============================] - 35s 20ms/step - loss: 0.2772 - acc: 0.9183 - val_loss: 2.4123 - val_acc: 0.4400
# Epoch 37/50
# 1800/1800 [==============================] - 35s 20ms/step - loss: 0.2655 - acc: 0.9239 - val_loss: 2.5389 - val_acc: 0.4150
# Epoch 38/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.2422 - acc: 0.9283 - val_loss: 2.5539 - val_acc: 0.4200
# Epoch 39/50
# 1800/1800 [==============================] - 35s 20ms/step - loss: 0.2291 - acc: 0.9322 - val_loss: 2.4380 - val_acc: 0.4350
# Epoch 40/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.2356 - acc: 0.9344 - val_loss: 2.5295 - val_acc: 0.4150
# Epoch 41/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.2156 - acc: 0.9339 - val_loss: 2.8688 - val_acc: 0.4300
# Epoch 42/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.1974 - acc: 0.9411 - val_loss: 2.5671 - val_acc: 0.4050
# Epoch 43/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.1878 - acc: 0.9489 - val_loss: 2.6774 - val_acc: 0.4300
# Epoch 44/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.1925 - acc: 0.9450 - val_loss: 2.6999 - val_acc: 0.4200
# Epoch 45/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.1966 - acc: 0.9383 - val_loss: 2.6514 - val_acc: 0.4150
# Epoch 46/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.1758 - acc: 0.9478 - val_loss: 2.5181 - val_acc: 0.4400
# Epoch 47/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.1960 - acc: 0.9367 - val_loss: 2.5391 - val_acc: 0.4100
# Epoch 48/50
# 1800/1800 [==============================] - 35s 20ms/step - loss: 0.1558 - acc: 0.9578 - val_loss: 2.5931 - val_acc: 0.4250
# Epoch 49/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.1914 - acc: 0.9428 - val_loss: 2.4737 - val_acc: 0.4600
# Epoch 50/50
# 1800/1800 [==============================] - 36s 20ms/step - loss: 0.1954 - acc: 0.9411 - val_loss: 2.6697 - val_acc: 0.4450

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  

plt.figure(figsize=(12,8))
plt.plot(hist2.history['val_acc'], label='Accuracy')
plt.title("Final accuracy on validation data (50 epochs): {:.3%}".format(hist2.history['val_acc'][-1:][0]))
plt.legend(loc=2)
_ = plt.show()
plt.savefig("acc.png")
